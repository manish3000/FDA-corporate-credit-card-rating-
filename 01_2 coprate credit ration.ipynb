# %% [markdown]
# # Task
# Clean the `corporate_rating.csv` dataset by inspecting it, merging rating classes, encoding target labels, handling missing values, and saving the cleaned data to "credit_ratings_tabular_clean.csv".

# %% [markdown]
# ## Load data
#
# ### Subtask:
# Load the `corporate_rating.csv` file into a pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# Import pandas and load the CSV file into a DataFrame.

# %%
import pandas as pd

df = pd.read_csv('corporate_rating.csv')

# %%
df.head()
# Out:
#   Rating                   Name Symbol                  Rating Agency Name  \
# 0      A  Whirlpool Corporation    WHR          Egan-Jones Ratings Company
# 1    BBB  Whirlpool Corporation    WHR          Egan-Jones Ratings Company
# 2    BBB  Whirlpool Corporation    WHR                       Fitch Ratings
# 3    BBB  Whirlpool Corporation    WHR                       Fitch Ratings
# 4    BBB  Whirlpool Corporation    WHR  Standard & Poor's Ratings Services
#
#          Date             Sector  currentRatio  quickRatio  cashRatio  \
# 0  11/27/2015  Consumer Durables      0.945894    0.426395   0.099690
# 1   2/13/2014  Consumer Durables      1.033559    0.498234   0.203120
# 2    3/6/2015  Consumer Durables      0.963703    0.451505   0.122099
# 3   6/15/2012  Consumer Durables      1.019851    0.510402   0.176116
# 4  10/24/2016  Consumer Durables      0.957844    0.495432   0.141608
#
#    daysOfSalesOutstanding  ...  effectiveTaxRate  \
# 0               44.203245  ...          0.202716
# 1               38.991156  ...          0.074155
# 2               50.841385  ...          0.214529
# 3               41.161738  ...          1.816667
# 4               47.761126  ...          0.166966
#
#    freeCashFlowOperatingCashFlowRatio  freeCashFlowPerShare  cashPerShare  \
# 0                            0.437551              6.810673      9.809403
# 1                            0.541997              8.625473     17.402270
# 2                            0.513185              9.693487     13.103448
# 3                           -0.147170             -1.015625     14.440104
# 4                            0.451372              7.135348     14.257556
#
#    companyEquityMultiplier  ebitPerRevenue  enterpriseValueMultiple  \
# 0                 4.008012        0.049351                 7.057088
# 1                 3.156783        0.048857                 6.460618
# 2                 4.094575        0.044334                10.491970
# 3                 3.630950       -0.012858                 4.080741
# 4                 4.012780        0.053770                 8.293505
#
#    operatingCashFlowPerShare  operatingCashFlowSalesRatio  payablesTurnover
# 0                  15.565438                     0.058638          3.906655
# 1                  15.914250                     0.067239          4.002846
# 2                  18.888889                     0.074426          3.483510
# 3                   6.901042                     0.028394          4.581150
# 4                  15.808147                     0.058065          3.857790
#
# [5 rows x 31 columns]

# %%
df.rename(columns={'Symbol': 'Ticker'}, inplace=True)

# %%
total_ticker=df["Ticker"].unique()
len(total_ticker)
# Out:
# 593

# %% [markdown]
# ## Initial inspection
#
# ### Subtask:
# Inspect column names, datatypes, missingness, and distributions.

# %% [markdown]
# **Reasoning**:
# Inspect the DataFrame by printing column names and their data types, calculating missing value percentages, generating descriptive statistics for numerical columns, and examining the distribution of the 'Rating' column to understand the data structure, identify potential issues like missing data, and understand the distribution of the target variable.

# %%
print(df.info())
print("\nPercentage of missing values:\n", df.isnull().sum() * 100 / len(df))
print("\nDescriptive statistics for numerical columns:\n", df.describe())
print("\nDistribution of the 'Rating' column:\n", df['Rating'].value_counts())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2029 entries, 0 to 2028
# Data columns (total 31 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Rating                              2029 non-null   object
#  1   Name                                2029 non-null   object
#  2   Ticker                              2029 non-null   object
#  3   Rating Agency Name                  2029 non-null   object
#  4   Date                                2029 non-null   object
#  5   Sector                              2029 non-null   object
#  6   currentRatio                        2029 non-null   float64
#  7   quickRatio                          2029 non-null   float64
#  8   cashRatio                           2029 non-null   float64
#  9   daysOfSalesOutstanding              2029 non-null   float64
#  10  netProfitMargin                     2029 non-null   float64
#  11  pretaxProfitMargin                  2029 non-null   float64
#  12  grossProfitMargin                   2029 non-null   float64
#  13  operatingProfitMargin               2029 non-null   float64
#  14  returnOnAssets                      2029 non-null   float64
#  15  returnOnCapitalEmployed             2029 non-null   float64
#  16  returnOnEquity                      2029 non-null   float64
#  17  assetTurnover                       2029 non-null   float64
#  18  fixedAssetTurnover                  2029 non-null   float64
#  19  debtEquityRatio                     2029 non-null   float64
#  20  debtRatio                           2029 non-null   float64
#  21  effectiveTaxRate                    2029 non-null   float64
#  22  freeCashFlowOperatingCashFlowRatio  2029 non-null   float64
#  23  freeCashFlowPerShare                2029 non-null   float64
#  24  cashPerShare                        2029 non-null   float64
#  25  companyEquityMultiplier             2029 non-null   float64
#  26  ebitPerRevenue                      2029 non-null   float64
#  27  enterpriseValueMultiple             2029 non-null   float64
#  28  operatingCashFlowPerShare           2029 non-null   float64
#  29  operatingCashFlowSalesRatio         2029 non-null   float64
#  30  payablesTurnover                    2029 non-null   float64
# dtypes: float64(25), object(6)
# memory usage: 491.5+ KB
# None
#
# Percentage of missing values:
#  Rating                                0.0
# Name                                  0.0
# Ticker                                0.0
# Rating Agency Name                    0.0
# Date                                  0.0
# Sector                                0.0
# currentRatio                          0.0
# quickRatio                            0.0
# cashRatio                             0.0
# daysOfSalesOutstanding                0.0
# netProfitMargin                       0.0
# pretaxProfitMargin                    0.0
# grossProfitMargin                     0.0
# operatingProfitMargin                 0.0
# returnOnAssets                        0.0
# returnOnCapitalEmployed               0.0
# returnOnEquity                        0.0
# assetTurnover                         0.0
# fixedAssetTurnover                    0.0
# debtEquityRatio                       0.0
# debtRatio                             0.0
# effectiveTaxRate                      0.0
# freeCashFlowOperatingCashFlowRatio    0.0
# freeCashFlowPerShare                  0.0
# cashPerShare                          0.0
# companyEquityMultiplier               0.0
# ebitPerRevenue                        0.0
# enterpriseValueMultiple               0.0
# operatingCashFlowPerShare             0.0
# operatingCashFlowSalesRatio           0.0
# payablesTurnover                      0.0
# dtype: float64
#
# Descriptive statistics for numerical columns:
#         currentRatio   quickRatio    cashRatio  daysOfSalesOutstanding  \
# count   2029.000000  2029.000000  2029.000000             2029.000000
# mean       3.529607     2.653986     0.667364              333.795606
# std       44.052361    32.944817     3.583943             4447.839583
# min       -0.932005    -1.893266    -0.192736             -811.845623
# 25%        1.071930     0.602825     0.130630               22.905093
# 50%        1.493338     0.985679     0.297493               42.374120
# 75%        2.166891     1.453820     0.624906               59.323563
# max     1725.505005  1139.541703   125.917417           115961.637400
#
#        netProfitMargin  pretaxProfitMargin  grossProfitMargin  \
# count      2029.000000         2029.000000        2029.000000
# mean          0.278447            0.431483           0.497968
# std           6.064134            8.984982           0.525307
# min        -101.845815         -124.343612         -14.800817
# 25%           0.021006            0.025649           0.233127
# 50%           0.064753            0.084965           0.414774
# 75%           0.114807            0.144763           0.849693
# max         198.517873          309.694856           2.702533
#
#        operatingProfitMargin  returnOnAssets  returnOnCapitalEmployed  ...  \
# count            2029.000000     2029.000000              2029.000000  ...
# mean                0.587322      -37.517928               -73.974193  ...
# std                11.224622     1166.172220              2350.275719  ...
# min              -124.343612   -40213.178290            -87162.162160  ...
# 25%                 0.044610        0.019176                 0.028112  ...
# 50%                 0.107895        0.045608                 0.074421  ...
# 75%                 0.176181        0.077468                 0.135036  ...
# max               410.182214        0.487826                 2.439504  ...
#
#        effectiveTaxRate  freeCashFlowOperatingCashFlowRatio  \
# count       2029.000000                         2029.000000
# mean           0.397572                            0.409550
# std           10.595075                            3.796488
# min         -100.611015                         -120.916010
# 25%            0.146854                            0.271478
# 50%            0.300539                            0.644529
# 75%            0.370653                            0.836949
# max          429.926282                           34.594086
#
#        freeCashFlowPerShare  cashPerShare  companyEquityMultiplier  \
# count          2.029000e+03  2.029000e+03              2029.000000
# mean           5.094719e+03  4.227549e+03                 3.323579
# std            1.469156e+05  1.224000e+05                87.529866
# min           -4.912742e+03 -1.915035e+01             -2555.419643
# 25%            4.119924e-01  1.566038e+00                 2.046822
# 50%            2.131742e+00  3.686513e+00                 2.652456
# 75%            4.230253e+00  8.086152e+00                 3.658331
# max            5.753380e+06  4.786803e+06              2562.871795
#
#        ebitPerRevenue  enterpriseValueMultiple  operatingCashFlowPerShare  \
# count     2029.000000              2029.000000               2.029000e+03
# mean         0.437454                48.287985               6.515123e+03
# std          8.984299               529.118961               1.775290e+05
# min       -124.343612             -3749.921337              -1.195049e+04
# 25%          0.028057                 6.238066               2.356735e+00
# 50%          0.087322                 9.274398               4.352584e+00
# 75%          0.149355                12.911759               7.319759e+00
# max        309.694856             11153.607090               6.439270e+06
#
#        operatingCashFlowSalesRatio  payablesTurnover
# count                  2029.000000       2029.000000
# mean                      1.447653         38.002718
# std                      19.483294        758.923588
# min                      -4.461837        -76.662850
# 25%                       0.073886          2.205912
# 50%                       0.133050          5.759722
# 75%                       0.240894          9.480892
# max                     688.526591      20314.880400
#
# [8 rows x 25 columns]
#
# Distribution of the 'Rating' column:
#  Rating
# BBB    671
# BB     490
# A      398
# B      302
# AA      89
# CCC     64
# AAA      7
# CC       5
# C        2
# D        1
# Name: count, dtype: int64

# %% [markdown]
# ## Merge rating classes
#
# ### Subtask:
# Map 'AAA' to 'AA+' and 'CC', 'C', 'D' to 'CCC–' to create 6 final classes.

# %% [markdown]
# **Reasoning**:
# Create a dictionary to map the original rating classes to the new 6 classes, apply this mapping to the 'Rating' column to create a new column 'Rating_Merged', and verify the distribution of the new column.

# %%
rating_mapping = {
    'AAA': 'AA+',
    'CC': 'CCC–',
    'C': 'CCC–',
    'D': 'CCC–'
}

df['Rating_Merged'] = df['Rating'].replace(rating_mapping)

print(df['Rating_Merged'].value_counts())
# Out:
# Rating_Merged
# BBB     671
# BB      490
# A       398
# B       302
# AA       89
# CCC      64
# CCC–      8
# AA+       7
# Name: count, dtype: int64

# %% [markdown]
# ## Encode target labels
#
# ### Subtask:
# Create both multiclass and binary (Investment Grade) encoded target labels.

# %% [markdown]
# **Reasoning**:
# Encode the 'Rating_Merged' column into both multiclass and binary labels, then display the value counts.

# %%
from sklearn.preprocessing import LabelEncoder

# Multiclass encoding
label_encoder = LabelEncoder()
df['Rating_Encoded_Multiclass'] = label_encoder.fit_transform(df['Rating_Merged'])

# Binary encoding (Investment Grade vs. Not Investment Grade)
investment_grade_ratings = ['AAA', 'AA+', 'AA', 'A+', 'A', 'A-', 'BBB+', 'BBB', 'BBB-']
df['Rating_Encoded_Binary'] = df['Rating_Merged'].apply(lambda x: 1 if x in investment_grade_ratings else 0)

# Display value counts for verification
print("Value counts for Multiclass Encoded Ratings:\n", df['Rating_Encoded_Multiclass'].value_counts())
print("\nValue counts for Binary Encoded Ratings:\n", df['Rating_Encoded_Binary'].value_counts())
# Out:
# Value counts for Multiclass Encoded Ratings:
#  Rating_Encoded_Multiclass
# 5    671
# 4    490
# 0    398
# 3    302
# 1     89
# 6     64
# 7      8
# 2      7
# Name: count, dtype: int64
#
# Value counts for Binary Encoded Ratings:
#  Rating_Encoded_Binary
# 1    1165
# 0     864
# Name: count, dtype: int64

# %% [markdown]
# ## Handle missing values
#
# ### Subtask:
# Implement a strategy for handling missing values, potentially using median imputation for ratios and KNN or iterative imputation for other features, while adding indicator columns for original missingness.

# %% [markdown]
# **Reasoning**:
# Identify columns with missing values and their types, then create indicator columns for missing values.

# %%
# Check for missing values
missing_values = df.isnull().sum()
missing_values = missing_values[missing_values > 0]

print("Columns with missing values:\n", missing_values)

# Create indicator columns for original missingness
for col in missing_values.index:
    df[col + '_missing_indicator'] = df[col].isnull().astype(int)

display(df.head())
# Out:
# Columns with missing values:
#  Series([], dtype: int64)
#   Rating                   Name Ticker                  Rating Agency Name  \
# 0      A  Whirlpool Corporation    WHR          Egan-Jones Ratings Company
# 1    BBB  Whirlpool Corporation    WHR          Egan-Jones Ratings Company
# 2    BBB  Whirlpool Corporation    WHR                       Fitch Ratings
# 3    BBB  Whirlpool Corporation    WHR                       Fitch Ratings
# 4    BBB  Whirlpool Corporation    WHR  Standard & Poor's Ratings Services
#
#          Date             Sector  currentRatio  quickRatio  cashRatio  \
# 0  11/27/2015  Consumer Durables      0.945894    0.426395   0.099690
# 1   2/13/2014  Consumer Durables      1.033559    0.498234   0.203120
# 2    3/6/2015  Consumer Durables      0.963703    0.451505   0.122099
# 3   6/15/2012  Consumer Durables      1.019851    0.510402   0.176116
# 4  10/24/2016  Consumer Durables      0.957844    0.495432   0.141608
#
#    daysOfSalesOutstanding  ...  cashPerShare  companyEquityMultiplier  \
# 0               44.203245  ...      9.809403                 4.008012
# 1               38.991156  ...     17.402270                 3.156783
# 2               50.841385  ...     13.103448                 4.094575
# 3               41.161738  ...     14.440104                 3.630950
# 4               47.761126  ...     14.257556                 4.012780
#
#    ebitPerRevenue  enterpriseValueMultiple  operatingCashFlowPerShare  \
# 0        0.049351                 7.057088                  15.565438
# 1        0.048857                 6.460618                  15.914250
# 2        0.044334                10.491970                  18.888889
# 3       -0.012858                 4.080741                   6.901042
# 4        0.053770                 8.293505                  15.808147
#
#    operatingCashFlowSalesRatio  payablesTurnover  Rating_Merged  \
# 0                     0.058638          3.906655              A
# 1                     0.067239          4.002846            BBB
# 2                     0.074426          3.483510            BBB
# 3                     0.028394          4.581150            BBB
# 4                     0.058065          3.857790            BBB
#
#    Rating_Encoded_Multiclass  Rating_Encoded_Binary
# 0                          0                      1
# 1                          5                      1
# 2                          5                      1
# 3                          5                      1
# 4                          5                      1
#
# [5 rows x 34 columns]

# %% [markdown]
# ## Save cleaned data
#
# ### Subtask:
# Save the cleaned tabular data to a new CSV file named `credit_ratings_tabular_clean.csv`.

# %% [markdown]
# **Reasoning**:
# Save the cleaned DataFrame to a CSV file without the index.

# %%
df.to_csv('01_credit_ratings_tabular_clean.csv', index=False)

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The initial dataset contained 2029 entries and 31 columns, with no missing values.
# *   The `Rating` column was successfully processed by merging 'AAA' to 'AA+' and 'CC', 'C', 'D' to 'CCC–', resulting in a new column `Rating_Merged` with 8 distinct classes.
# *   Two new target label columns were created: `Rating_Encoded_Multiclass` (8 classes) and `Rating_Encoded_Binary` (Investment Grade vs. Not Investment Grade).
#
# ### Insights or Next Steps
#
# *   The absence of missing values simplifies the data preparation process, allowing for direct use in modeling.
# *   Further analysis should investigate the distribution of the merged and encoded rating classes, particularly the low counts in some categories, which might impact model training.

# %% [markdown]
# ## reating data as year quater

# %%
# Ensure rating_date is a datetime
df['rating_date'] = pd.to_datetime(df['Date'], errors='coerce')

# Define a helper function to map to fiscal quarter
def get_fiscal_quarter(date):
    """Return fiscal year and quarter string (e.g., 2024_Q1) for given date."""
    year = date.year
    qtr = (date.month - 1) // 3 + 1
    return f"{year}_Q{qtr}"

df['year_qtr'] = df['rating_date'].apply(get_fiscal_quarter)

# %%
df.head()
# Out:
#   Rating                   Name Ticker                  Rating Agency Name  \
# 0      A  Whirlpool Corporation    WHR          Egan-Jones Ratings Company
# 1    BBB  Whirlpool Corporation    WHR          Egan-Jones Ratings Company
# 2    BBB  Whirlpool Corporation    WHR                       Fitch Ratings
# 3    BBB  Whirlpool Corporation    WHR                       Fitch Ratings
# 4    BBB  Whirlpool Corporation    WHR  Standard & Poor's Ratings Services
#
#          Date             Sector  currentRatio  quickRatio  cashRatio  \
# 0  11/27/2015  Consumer Durables      0.945894    0.426395   0.099690
# 1   2/13/2014  Consumer Durables      1.033559    0.498234   0.203120
# 2    3/6/2015  Consumer Durables      0.963703    0.451505   0.122099
# 3   6/15/2012  Consumer Durables      1.019851    0.510402   0.176116
# 4  10/24/2016  Consumer Durables      0.957844    0.495432   0.141608
#
#    daysOfSalesOutstanding  ...  ebitPerRevenue  enterpriseValueMultiple  \
# 0               44.203245  ...        0.049351                 7.057088
# 1               38.991156  ...        0.048857                 6.460618
# 2               50.841385  ...        0.044334                10.491970
# 3               41.161738  ...       -0.012858                 4.080741
# 4               47.761126  ...        0.053770                 8.293505
#
#    operatingCashFlowPerShare  operatingCashFlowSalesRatio  payablesTurnover  \
# 0                  15.565438                     0.058638          3.906655
# 1                  15.914250                     0.067239          4.002846
# 2                  18.888889                     0.074426          3.483510
# 3                   6.901042                     0.028394          4.581150
# 4                  15.808147                     0.058065          3.857790
#
#    Rating_Merged  Rating_Encoded_Multiclass  Rating_Encoded_Binary  \
# 0              A                          0                      1
# 1            BBB                          5                      1
# 2            BBB                          5                      1
# 3            BBB                          5                      1
# 4            BBB                          5                      1
#
#    rating_date  year_qtr
# 0   2015-11-27   2015_Q4
# 1   2014-02-13   2014_Q1
# 2   2015-03-06   2015_Q1
# 3   2012-06-15   2012_Q2
# 4   2016-10-24   2016_Q4
#
# [5 rows x 36 columns]

# %%
df["Sector"].unique()
# Out:
# array(['Consumer Durables', 'Energy', 'Capital Goods',
#        'Consumer Non-Durables', 'Public Utilities', 'Technology',
#        'Health Care', 'Consumer Services', 'Miscellaneous',
#        'Basic Industries', 'Finance', 'Transportation'], dtype=object)

# %% [markdown]
# ## now extract data from HTML files

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\manish\anaconda3\lib\site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\manish\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# from bs4 import BeautifulSoup, NavigableString
# import re
# import os

# # Function to extract MD&A from HTML file
# def extract_mda_from_html(file_path):
#     """
#     Extract Management Discussion & Analysis (MD&A) section from an HTML file.
#     Returns the extracted text or None if extraction fails.
#     """
#     try:
#         with open(file_path, "r", encoding="utf-8") as f:
#             html = f.read()
#     except Exception as e:
#         print(f"Error reading file {file_path}: {e}")
#         return None
    
#     soup = BeautifulSoup(html, "html.parser")
    
#     # Regex patterns for start and end
#     pattern_start = re.compile(
#         r"management['']s discussion and analysis", re.IGNORECASE
#     )
    
#     pattern_end = re.compile(
#         r"quantitative.*qualitative", re.IGNORECASE
#     )
    
#     start_href = None
#     end_href = None
    
#     # Find start and end hrefs
#     for a in soup.find_all("a"):
#         text = a.get_text(" ", strip=True)
#         if pattern_start.search(text):
#             start_href = a.get("href")
#             break
    
#     for a in soup.find_all("a"):
#         text = a.get_text(" ", strip=True)
#         if pattern_end.search(text):
#             end_href = a.get("href")
#             break
    
#     if not start_href or not end_href:
#         return None
    
#     # Function to find anchor target
#     def find_anchor_target(href):
#         if not href:
#             return None
        
#         if href.startswith("#"):
#             anchor_name = href[1:]
            
#             # Try ID first
#             t = soup.find(id=anchor_name)
#             if t:
#                 return t
            
#             # Try <a name="">
#             t = soup.find("a", attrs={"name": anchor_name})
#             if t:
#                 return t
            
#             # Try any tag with name=""
#             t = soup.find(attrs={"name": anchor_name})
#             if t:
#                 return t
        
#         return None
    
#     start_anchor = find_anchor_target(start_href)
#     end_anchor = find_anchor_target(end_href)
    
#     if not start_anchor or not end_anchor:
#         return None
    
#     # Extract text between anchors
#     texts = []
    
#     for elem in start_anchor.next_elements:
#         if elem == end_anchor:
#             break
        
#         if isinstance(elem, NavigableString):
#             t = str(elem).strip()
#             if t:
#                 texts.append(t)
    
#     extracted_text = " ".join(texts)
    
#     return extracted_text if extracted_text else None


# # Function to get HTML file path based on Ticker and year_qtr
# def get_html_file_path(ticker, year_qtr):
#     """
#     Construct the path to the HTML file based on Ticker and year_qtr.
#     Example: ticker='HON', year_qtr='2016_Q4' -> 'sec_filings/HON/2016_Q4.html'
#     """
#     base_path = os.path.join("sec_filings", ticker, f"{year_qtr}.html")
#     return base_path


# # Extract MD&A for each row
# print("Extracting MD&A from HTML files...")

# mda_list = []
# success_count = 0
# failed_count = 0

# for idx, row in df.iterrows():
#     ticker = row['Ticker']
#     year_qtr = row['year_qtr']
    
#     html_path = get_html_file_path(ticker, year_qtr)
    
#     if os.path.exists(html_path):
#         print(f"Processing {idx}: {ticker} - {year_qtr}...", end=" ")
#         mda_text = extract_mda_from_html(html_path)
#         if mda_text:
#             mda_list.append(mda_text)
#             success_count += 1
#             print("SUCCESS")
#         else:
#             mda_list.append(None)
#             failed_count += 1
#             print("FAILED")
#     else:
#         print(f"Skipping {idx}: File not found - {html_path}")
#         mda_list.append(None)
#         failed_count += 1

# # Add MD&A column to dataframe
# df['md&a'] = mda_list

# print(f"\nExtraction complete!")
# print(f"Success: {success_count}, Failed/Not Found: {failed_count}")
# print(f"\nMD&A column created. Sample:")
# print(df[['Ticker', 'year_qtr', 'md&a']].head())

# # Check how many rows have MD&A data
# print(f"\nRows with MD&A data: {df['md&a'].notna().sum()}")
# print(f"Rows without MD&A data: {df['md&a'].isna().sum()}")

# %%
df.head()
# Out:
#   Rating                   Name Ticker                  Rating Agency Name  \
# 0      A  Whirlpool Corporation    WHR          Egan-Jones Ratings Company
# 1    BBB  Whirlpool Corporation    WHR          Egan-Jones Ratings Company
# 2    BBB  Whirlpool Corporation    WHR                       Fitch Ratings
# 3    BBB  Whirlpool Corporation    WHR                       Fitch Ratings
# 4    BBB  Whirlpool Corporation    WHR  Standard & Poor's Ratings Services
#
#          Date             Sector  currentRatio  quickRatio  cashRatio  \
# 0  11/27/2015  Consumer Durables      0.945894    0.426395   0.099690
# 1   2/13/2014  Consumer Durables      1.033559    0.498234   0.203120
# 2    3/6/2015  Consumer Durables      0.963703    0.451505   0.122099
# 3   6/15/2012  Consumer Durables      1.019851    0.510402   0.176116
# 4  10/24/2016  Consumer Durables      0.957844    0.495432   0.141608
#
#    daysOfSalesOutstanding  ...  ebitPerRevenue  enterpriseValueMultiple  \
# 0               44.203245  ...        0.049351                 7.057088
# 1               38.991156  ...        0.048857                 6.460618
# 2               50.841385  ...        0.044334                10.491970
# 3               41.161738  ...       -0.012858                 4.080741
# 4               47.761126  ...        0.053770                 8.293505
#
#    operatingCashFlowPerShare  operatingCashFlowSalesRatio  payablesTurnover  \
# 0                  15.565438                     0.058638          3.906655
# 1                  15.914250                     0.067239          4.002846
# 2                  18.888889                     0.074426          3.483510
# 3                   6.901042                     0.028394          4.581150
# 4                  15.808147                     0.058065          3.857790
#
#    Rating_Merged  Rating_Encoded_Multiclass  Rating_Encoded_Binary  \
# 0              A                          0                      1
# 1            BBB                          5                      1
# 2            BBB                          5                      1
# 3            BBB                          5                      1
# 4            BBB                          5                      1
#
#    rating_date  year_qtr
# 0   2015-11-27   2015_Q4
# 1   2014-02-13   2014_Q1
# 2   2015-03-06   2015_Q1
# 3   2012-06-15   2012_Q2
# 4   2016-10-24   2016_Q4
#
# [5 rows x 36 columns]

# %%
from bs4 import BeautifulSoup, NavigableString
import re
import os

# Improved MD&A extraction function with multiple strategies
def extract_mda_from_html(file_path, verbose=False):
    """
    Extract Management Discussion & Analysis (MD&A) section from an HTML file.
    Uses multiple strategies to find the MD&A section.
    """
    try:
        with open(file_path, "r", encoding="utf-8", errors='ignore') as f:
            html = f.read()
    except Exception as e:
        if verbose:
            print(f"Error reading file {file_path}: {e}")
        return None
    
    soup = BeautifulSoup(html, "html.parser")
    
    # Strategy 1: Look for MD&A in table of contents links
    mda_text = extract_mda_via_toc(soup)
    if mda_text:
        return mda_text
    
    # Strategy 2: Look for MD&A by section headings
    mda_text = extract_mda_via_headings(soup)
    if mda_text:
        return mda_text
    
    # Strategy 3: Look for MD&A by common patterns
    mda_text = extract_mda_via_patterns(soup)
    if mda_text:
        return mda_text
    
    return None

def extract_mda_via_toc(soup):
    """Extract MD&A using table of contents links."""
    # Regex patterns for start and end
    pattern_start = re.compile(
        r"management[’'s]*\s*discussion\s*and\s*analysis", 
        re.IGNORECASE
    )
    
    pattern_end = re.compile(
        r"(quantitative.*qualitative|risk\s*factors|financial\s*statements|notes\s*to\s*financial)",
        re.IGNORECASE
    )
    
    start_href = None
    end_href = None
    
    # Find start and end hrefs
    for a in soup.find_all("a"):
        text = a.get_text(" ", strip=True)
        if pattern_start.search(text):
            start_href = a.get("href")
            break
    
    if not start_href:
        return None
    
    # Look for end marker
    for a in soup.find_all("a"):
        text = a.get_text(" ", strip=True)
        if pattern_end.search(text):
            end_href = a.get("href")
            break
    
    # Function to find anchor target
    def find_anchor_target(href):
        if not href:
            return None
        
        if href.startswith("#"):
            anchor_name = href[1:]
            
            # Try ID first
            t = soup.find(id=anchor_name)
            if t:
                return t
            
            # Try <a name="">
            t = soup.find("a", attrs={"name": anchor_name})
            if t:
                return t
            
            # Try any tag with name=""
            t = soup.find(attrs={"name": anchor_name})
            if t:
                return t
        
        return None
    
    start_anchor = find_anchor_target(start_href)
    end_anchor = find_anchor_target(end_href) if end_href else None
    
    # Extract text
    return extract_text_between_anchors(soup, start_anchor, end_anchor)

def extract_mda_via_headings(soup):
    """Extract MD&A by looking for section headings."""
    # Common MD&A headings
    mda_patterns = [
        re.compile(r"ITEM\s*[78]\.?\s*MANAGEMENT['S]*\s*DISCUSSION\s*AND\s*ANALYSIS", re.IGNORECASE),
        re.compile(r"MANAGEMENT['S]*\s*DISCUSSION\s*AND\s*ANALYSIS", re.IGNORECASE),
        re.compile(r"MD&A", re.IGNORECASE),
    ]
    
    # Common end patterns
    end_patterns = [
        re.compile(r"QUANTITATIVE\s*AND\s*QUALITATIVE", re.IGNORECASE),
        re.compile(r"ITEM\s*[78][A-Z]*\.?", re.IGNORECASE),
        re.compile(r"RISK\s*FACTORS", re.IGNORECASE),
        re.compile(r"FINANCIAL\s*STATEMENTS", re.IGNORECASE),
    ]
    
    # Look for MD&A heading
    start_element = None
    for pattern in mda_patterns:
        for tag in soup.find_all(['h1', 'h2', 'h3', 'h4', 'div', 'p', 'b', 'strong']):
            text = tag.get_text(strip=True)
            if pattern.search(text):
                start_element = tag
                break
        if start_element:
            break
    
    if not start_element:
        return None
    
    # Look for end marker
    end_element = None
    for pattern in end_patterns:
        for sibling in start_element.find_next_siblings():
            text = sibling.get_text(strip=True)
            if pattern.search(text) and len(text) < 100:  # Likely a heading
                end_element = sibling
                break
        if end_element:
            break
    
    return extract_text_between_elements(soup, start_element, end_element)

def extract_mda_via_patterns(soup):
    """Extract MD&A by looking for patterns in text."""
    # Get all text
    all_text = soup.get_text()
    
    # Find MD&A section
    mda_pattern = re.compile(
        r'(ITEM\s*[78]\.?\s*)?MANAGEMENT[’\'\"]?S\s*DISCUSSION\s*AND\s*ANALYSIS.*?(?=ITEM\s*[78][A-Z]*|QUANTITATIVE\s*AND\s*QUALITATIVE|RISK\s*FACTORS|FINANCIAL\s*STATEMENTS|$)',
        re.IGNORECASE | re.DOTALL
    )
    
    match = mda_pattern.search(all_text)
    if match:
        # Clean up the extracted text
        mda_text = match.group(0)
        # Remove excessive whitespace
        mda_text = re.sub(r'\s+', ' ', mda_text)
        return mda_text.strip()
    
    return None

def extract_text_between_anchors(soup, start_anchor, end_anchor):
    """Extract text between two anchors."""
    if not start_anchor:
        return None
    
    texts = []
    
    for elem in start_anchor.next_elements:
        if elem == end_anchor:
            break
        
        if isinstance(elem, NavigableString):
            t = str(elem).strip()
            if t and len(t) > 5:  # Skip very short strings
                texts.append(t)
    
    if not texts:
        return None
    
    extracted_text = " ".join(texts)
    # Clean up the text
    extracted_text = re.sub(r'\s+', ' ', extracted_text)
    return extracted_text[:10000]  # Limit to first 10k characters

def extract_text_between_elements(soup, start_element, end_element):
    """Extract text between two elements."""
    texts = []
    
    current = start_element.next_sibling
    while current and current != end_element:
        if isinstance(current, NavigableString):
            t = str(current).strip()
            if t and len(t) > 5:
                texts.append(t)
        elif current.name in ['p', 'div', 'span']:
            text = current.get_text(strip=True)
            if text and len(text) > 10:
                texts.append(text)
        
        if hasattr(current, 'next_sibling'):
            current = current.next_sibling
        else:
            break
    
    if not texts:
        return None
    
    extracted_text = " ".join(texts)
    extracted_text = re.sub(r'\s+', ' ', extracted_text)
    return extracted_text[:10000]

# Function to get HTML file path
def get_html_file_path(ticker, year_qtr, base_dir="sec_filings"):
    """Construct the path to the HTML file."""
    # Try different possible file locations
    possible_paths = [
        os.path.join(base_dir, ticker, f"{year_qtr}.html"),
        os.path.join(base_dir, ticker, f"{year_qtr.lower()}.html"),
        os.path.join(base_dir, ticker, year_qtr, "filing.html"),
        os.path.join(base_dir, ticker, year_qtr.replace("_", ""), "filing.html"),
    ]
    
    for path in possible_paths:
        if os.path.exists(path):
            return path
    
    return None

# Main extraction with better logging
print("Extracting MD&A from HTML files...\n")

mda_list = []
success_count = 0
failed_count = 0

for idx, row in df.iterrows():
    ticker = row['Ticker']
    year_qtr = row['year_qtr']
    
    html_path = get_html_file_path(ticker, year_qtr)
    
    if html_path and os.path.exists(html_path):
        print(f"Processing {idx}: {ticker} - {year_qtr}")
        print(f"  File: {html_path}")
        
        mda_text = extract_mda_from_html(html_path, verbose=True)
        
        if mda_text:
            # Truncate and show preview
            preview = mda_text[:200] + "..." if len(mda_text) > 200 else mda_text
            print(f"  SUCCESS: Extracted {len(mda_text)} characters")
            print(f"  Preview: {preview}")
            mda_list.append(mda_text)
            success_count += 1
        else:
            print(f"  FAILED: Could not extract MD&A")
            mda_list.append(None)
            failed_count += 1
    else:
        print(f"Skipping {idx}: File not found - {ticker}/{year_qtr}")
        mda_list.append(None)
        failed_count += 1
    
    print()

# Add MD&A column to dataframe
df['md&a'] = mda_list

print(f"Extraction complete!")
print(f"Success: {success_count}, Failed/Not Found: {failed_count}")
print(f"Success rate: {success_count/len(df)*100:.1f}%")

# Save the enhanced dataframe
df.to_csv('02_credit_ratings_with_mda.csv', index=False)
print(f"\\nSaved enhanced data to '02_credit_ratings_with_mda.csv'")

# Show statistics
print(f"\\nRows with MD&A data: {df['md&a'].notna().sum()}")
print(f"Rows without MD&A data: {df['md&a'].isna().sum()}")

# Preview rows with MD&A
if df['md&a'].notna().any():
    print("\\nSample of extracted MD&A data:")
    preview_df = df[df['md&a'].notna()][['Ticker', 'year_qtr', 'Rating']].head()
    for _, row in preview_df.iterrows():
        print(f"  {row['Ticker']} ({row['year_qtr']}) - Rating: {row['Rating']}")
# Out:
# Extracting MD&A from HTML files...
#
# Processing 0: WHR - 2015_Q4
#   File: sec_filings\WHR\2015_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: ABOUT WHIRLPOOL Whirlpool is the number one major appliance manufacturer in the world with net sales of approximately $20 billion and net earnings available to Whirlpool of $650 million . We are a lea...
#
# Processing 1: WHR - 2014_Q1
#   File: sec_filings\WHR\2014_Q1.html
#   SUCCESS: Extracted 10000 characters
#   Preview: ABOUT WHIRLPOOL Whirlpool Corporation (“Whirlpool”) is the world’s leading manufacturer of major home appliances with revenues of approximately $18 billion and net earnings available to Whirlpool of $...
#
# Processing 2: WHR - 2015_Q1
#   File: sec_filings\WHR\2015_Q1.html
#   SUCCESS: Extracted 10000 characters
#   Preview: ITEM 7. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS This Management Discussion and Analysis should be read in connection with the Consolidated Financial State...
#
# Processing 3: WHR - 2012_Q2
#   File: sec_filings\WHR\2012_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: ABOUT WHIRLPOOL Whirlpool Corporation (“Whirlpool”) is the world’s leading manufacturer of major home appliances with revenues of approximately $19 billion and net earnings available to Whirlpool of $...
#
# Processing 4: WHR - 2016_Q4
#   File: sec_filings\WHR\2016_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: ABOUT WHIRLPOOL Whirlpool Corporation ("Whirlpool") is the number one major appliance manufacturer in the world with net sales of approximately $21 billion and net earnings available to Whirlpool of $...
#
# Processing 5: SLB - 2014_Q3
#   File: sec_filings\SLB\2014_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Management’s Discussion and Analysis of Financial Condition and Results of Operations. First Quarter 2014 Compared to Fourth Quarter 2013 Product Groups (Stated in millions) First Quarter 2014 Fourth ...
#
# Processing 6: SLB - 2014_Q2
#   File: sec_filings\SLB\2014_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Management’s Discussion and Analysis of Financial Condition and Results of Operations. First Quarter 2014 Compared to Fourth Quarter 2013 Product Groups (Stated in millions) First Quarter 2014 Fourth ...
#
# Processing 7: SLB - 2015_Q3
#   File: sec_filings\SLB\2015_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations. Second Quarter 2015 Compared to First Quarter 2015 Product Groups (Stated in millions) Second Quarter 201...
#
# Processing 8: HON - 2014_Q2
#   File: sec_filings\HON\2014_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: ITEM 2. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS (MD&A) (Dollars in millions, except per share amounts) The following MD&A is intended to help the reader u...
#
# Processing 9: HON - 2016_Q1
#   File: sec_filings\HON\2016_Q1.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Management’s Discussion and Analysis of Financial Condition and Results of Operations (Dollars in millions, except per share amounts) The following Management’s Discussion and Analysis of Financial Co...
#
# Processing 10: HON - 2015_Q2
#   File: sec_filings\HON\2015_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: ITEM 2. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS (MD&A) (Dollars in millions, except per share amounts) The following MD&A is intended to help the reader u...
#
# Processing 11: SYY - 2015_Q2
#   File: sec_filings\SYY\2015_Q2.html
#   SUCCESS: Extracted 4359 characters
#   Preview: 50EXHIBIT INDEXExhibits.2.1—Agreement and Plan of Merger, dated as of December 8, 2013, by and among Sysco Corporation, USF Holding Corp., Scorpion Corporation I, Inc. and Scorpion Company II, LLC, in...
#
# Processing 12: SYY - 2014_Q2
#   File: sec_filings\SYY\2014_Q2.html
#   SUCCESS: Extracted 3794 characters
#   Preview: 47EXHIBIT INDEXExhibits.2.1—Agreement and Plan of Merger, dated as of December 8, 2013, by and among Sysco Corporation, USF Holding Corp., Scorpion Corporation I, Inc. and Scorpion Company II, LLC, in...
#
# Processing 13: SYY - 2015_Q4
#   File: sec_filings\SYY\2015_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Forward-Looking Statements Certain statements made herein that look forward in time or express management’s expectations or beliefs with respect to the occurrence of future events are forward-looking ...
#
# Processing 14: SYY - 2013_Q2
#   File: sec_filings\SYY\2013_Q2.html
#   SUCCESS: Extracted 2267 characters
#   Preview: 43EXHIBIT INDEXExhibits.3.1—Restated Certificate of Incorporation, incorporated by reference to Exhibit 3(a) to Form 10-K for the year ended June 28, 1997 (File No. 1-6544).3.2—Certificate of Amendmen...
#
# Processing 15: PM - 2016_Q1
#   File: sec_filings\PM\2016_Q1.html
#   SUCCESS: Extracted 10000 characters
#   Preview: ŸWe may be unsuccessful in our attempts to introduce Reduced-Risk Products, and regulators may not permit reduced exposure or risk claims or the commercialization of these products. We continue to see...
#
# Processing 16: PM - 2013_Q3
#   File: sec_filings\PM\2013_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Table of Contents Item 2. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS Description of Our Company We are a holding company whose subsidiaries and affiliates, a...
#
# Processing 17: PM - 2013_Q1
#   File: sec_filings\PM\2013_Q1.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Table of Contents Item 2. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS Description of Our Company We are a holding company whose subsidiaries and affiliates, a...
#
# Processing 18: PM - 2014_Q4
#   File: sec_filings\PM\2014_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Table of Contents Item 2. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS Description of Our Company We are a holding company whose subsidiaries and affiliates, a...
#
# Processing 19: PM - 2012_Q2
#   File: sec_filings\PM\2012_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Table of Contents Item 2. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS Description of Our Company We are a holding company whose subsidiaries and affiliates, a...
#
# Processing 20: T - 2014_Q4
#   File: sec_filings\T\2014_Q4.html
#   SUCCESS: Extracted 667 characters
#   Preview: Management’s Discussion and Analysis of Financial Condition and Results of Operations Dollars in millions except per share amounts RESULTS OF OPERATIONS For ease of reading, AT&T Inc. is referred to a...
#
# Processing 21: T - 2012_Q2
#   File: sec_filings\T\2012_Q2.html
#   SUCCESS: Extracted 700 characters
#   Preview: Management’s Discussion and Analysis of Financial Condition and Results of Operations Dollars in millions except per share amounts RESULTS OF OPERATIONS For ease of reading, AT&T Inc. is referred to a...
#
# Processing 22: T - 2016_Q4
#   File: sec_filings\T\2016_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: RESULTS OF OPERATIONS For ease of reading, AT&T Inc. is referred to as "we," "AT&T" or the "Company" throughout this document, and the names of the particular subsidiaries and affiliates providing the...
#
# Processing 23: T - 2012_Q4
#   File: sec_filings\T\2012_Q4.html
#   SUCCESS: Extracted 813 characters
#   Preview: Management’s Discussion and Analysis of Financial Condition and Results of Operations Dollars in millions except per share amounts RESULTS OF OPERATIONS For ease of reading, AT&T Inc. is referred to a...
#
# Processing 24: DUK - 2013_Q3
#   File: sec_filings\DUK\2013_Q3.html
#   SUCCESS: Extracted 97 characters
#   Preview: Management’s Discussion and Analysis of Financial Condition and Results of Operations 104 Item 3.
#
# Processing 25: DUK - 2015_Q2
#   File: sec_filings\DUK\2015_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: PART I ITEM 2. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS The following combined Management’s Discussion and Analysis of Financial Condition and Results of O...
#
# Processing 26: DUK - 2015_Q3
#   File: sec_filings\DUK\2015_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: PART I ITEM 2. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS The following combined Management’s Discussion and Analysis of Financial Condition and Results of O...
#
# Processing 27: DUK - 2013_Q2
#   File: sec_filings\DUK\2013_Q2.html
#   SUCCESS: Extracted 97 characters
#   Preview: Management’s Discussion and Analysis of Financial Condition and Results of Operations 102 Item 3.
#
# Processing 28: DUK - 2012_Q2
#   File: sec_filings\DUK\2012_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 7. Management’s Discussion and Analysis of Financial Condition and Results of Operations. INTRODUCTION Duke Energy Corporation (collectively with its subsidiaries, Duke Energy) is an energy compa...
#
# Processing 29: DUK - 2016_Q3
#   File: sec_filings\DUK\2016_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: PART I ITEM 2. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS The following combined Management’s Discussion and Analysis of Financial Condition and Results of O...
#
# Processing 30: DHR - 2014_Q2
#   File: sec_filings\DHR\2014_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Table of Contents ITEM 2. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS Management’s Discussion and Analysis of Financial Condition and Results of Operations (“...
#
# Processing 31: DHR - 2014_Q3
#   File: sec_filings\DHR\2014_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Table of Contents ITEM 2. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS Management’s Discussion and Analysis of Financial Condition and Results of Operations (“...
#
# Processing 32: DHR - 2015_Q4
#   File: sec_filings\DHR\2015_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Table of Contents ITEM 2. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS Management’s Discussion and Analysis of Financial Condition and Results of Operations (“...
#
# Processing 33: DHR - 2012_Q2
#   File: sec_filings\DHR\2012_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: ITEM 2. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS Management’s Discussion and Analysis of Financial Condition and Results of Operations (“MD&A”) is designed...
#
# Processing 34: CACI - 2016_Q2
#   File: sec_filings\CACI\2016_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2. Management’s Discussion and Analysis o f Financial Condition and Results of Operations There are statements made herein which do not address historical facts and, therefore, could be interpret...
#
# Processing 35: CACI - 2014_Q4
#   File: sec_filings\CACI\2014_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations There are statements made herein which do not address historical facts and, therefore, could be interprete...
#
# Processing 36: CACI - 2013_Q4
#   File: sec_filings\CACI\2013_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations Forward Looking Statements There are statements made herein which do not address historical facts and, the...
#
# Processing 37: CACI - 2016_Q3
#   File: sec_filings\CACI\2016_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 7. Management’s Discussio n and Analysis of Financial Condition & Results of Operations The following discussion and analysis of our financial condition and results of operations is provided to e...
#
# Processing 38: SWX - 2014_Q3
#   File: sec_filings\SWX\2014_Q3.html
#   FAILED: Could not extract MD&A
#
# Processing 39: SWX - 2012_Q2
#   File: sec_filings\SWX\2012_Q2.html
#   FAILED: Could not extract MD&A
#
# Processing 40: SWX - 2014_Q2
#   File: sec_filings\SWX\2014_Q2.html
#   FAILED: Could not extract MD&A
#
# Processing 41: SWX - 2011_Q2
#   File: sec_filings\SWX\2011_Q2.html
#   FAILED: Could not extract MD&A
#
# Processing 42: SWX - 2013_Q2
#   File: sec_filings\SWX\2013_Q2.html
#   FAILED: Could not extract MD&A
#
# Processing 43: SWX - 2016_Q1
#   File: sec_filings\SWX\2016_Q1.html
#   FAILED: Could not extract MD&A
#
# Skipping 44: File not found - AMOV/2012_Q2
#
# Processing 45: NKTR - 2015_Q4
#   File: sec_filings\NKTR\2015_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations The following discussion contains forward-looking statements that involve risks and uncertainties. Our act...
#
# Processing 46: NKTR - 2015_Q2
#   File: sec_filings\NKTR\2015_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations The following discussion contains forward-looking statements that involve risks and uncertainties. Our act...
#
# Processing 47: NKTR - 2014_Q2
#   File: sec_filings\NKTR\2014_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations The following discussion contains forward-looking statements that involve risks and uncertainties. Our act...
#
# Processing 48: NKTR - 2013_Q2
#   File: sec_filings\NKTR\2013_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations The following discussion contains forward-looking statements that involve risks and uncertainties. Our act...
#
# Processing 49: WEC - 2015_Q2
#   File: sec_filings\WEC\2015_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Proposed Acquisition:On June 22, 2014, we entered into an agreement to acquire Integrys. The proposed acquisition is scheduled to close by the end of this summer, and is subject to the receipt of vari...
#
# Processing 50: WEC - 2013_Q4
#   File: sec_filings\WEC\2013_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: We have prepared the unaudited interim financial statements presented in this Form 10-Q pursuant to the rules and regulations of the SEC. We have condensed or omitted some information and note disclos...
#
# Processing 51: WEC - 2015_Q3
#   File: sec_filings\WEC\2015_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: June 20152WEC Energy Group, Inc. DEFINITION OF ABBREVIATIONS AND INDUSTRY TERMSThe abbreviations and terms set forth below are used throughout this report and have the meanings assigned to them below:...
#
# Processing 52: FE - 2015_Q3
#   File: sec_filings\FE\2015_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: GLOSSARY OF TERMS The following abbreviations and acronyms are used in this report to identify FirstEnergy Corp. and its current and former subsidiaries: AEAllegheny Energy, Inc., a Maryland utility h...
#
# Processing 53: FE - 2014_Q2
#   File: sec_filings\FE\2014_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: GLOSSARY OF TERMS The following abbreviations and acronyms are used in this report to identify FirstEnergy Corp. and its current and former subsidiaries: AEAllegheny Energy, Inc., a Maryland utility h...
#
# Processing 54: FE - 2014_Q3
#   File: sec_filings\FE\2014_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: GLOSSARY OF TERMS The following abbreviations and acronyms are used in this report to identify FirstEnergy Corp. and its current and former subsidiaries: AEAllegheny Energy, Inc., a Maryland utility h...
#
# Processing 55: FE - 2012_Q2
#   File: sec_filings\FE\2012_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2. Management’s Discussion and Analysis of Registrant and Subsidiaries FIRSTENERGY CORP. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS OVERVIEW Earnings Av...
#
# Processing 56: FE - 2013_Q1
#   File: sec_filings\FE\2013_Q1.html
#   SUCCESS: Extracted 223 characters
#   Preview: Item 7. Management’s Discussion and Analysis of Registrant and Subsidiaries43FirstEnergy Corp.44iTABLE OF CONTENTS (Continued) Page FirstEnergy Solutions Corp.105Ohio Edison Company110Jersey Central P...
#
# Processing 57: VGR - 2013_Q4
#   File: sec_filings\VGR\2013_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: ITEM 2. MANAGEMENT'S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS Dollars in Thousands, Except Per Share Amounts Overview We are a holding company and are engaged principal...
#
# Processing 58: VGR - 2015_Q3
#   File: sec_filings\VGR\2015_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: ITEM 2. MANAGEMENT'S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS Dollars in Thousands, Except Per Share Amounts Management’s Discussion and Analysis of Financial Condition...
#
# Processing 59: VGR - 2011_Q4
#   File: sec_filings\VGR\2011_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: ITEM 2. MANAGEMENT'S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS Dollars in Thousands, Except Per Share Amounts Overview We are a holding company and are engaged principal...
#
# Processing 60: VGR - 2016_Q4
#   File: sec_filings\VGR\2016_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: VECTOR GROUP LTD. AND SUBSIDIARIESCONDENSED CONSOLIDATED BALANCE SHEETS(Dollars in Thousands, Except Per Share Amounts)Unaudited September 30,2016December 31,2015ASSETS:Current assets:Cash and cash eq...
#
# Processing 61: VGR - 2013_Q1
#   File: sec_filings\VGR\2013_Q1.html
#   SUCCESS: Extracted 10000 characters
#   Preview: ITEM 2. MANAGEMENT'S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS Dollars in Thousands, Except Per Share Amounts Overview We are a holding company and are engaged principal...
#
# Processing 62: CMS - 2013_Q4
#   File: sec_filings\CMS\2013_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS This MD&A is a combined report of CMS Energy and Consumers. EXECUTIVE OVERVIEW CMS Energy is an energy company operating primarily in Michigan. It is t...
#
# Processing 63: CMS - 2015_Q4
#   File: sec_filings\CMS\2015_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: This MD&A is a combined report of CMS Energy and Consumers. EXECUTIVE OVERVIEW CMS Energy is an energy company operating primarily in Michigan. It is the parent holding company of several subsidiaries...
#
# Processing 64: CMS - 2015_Q1
#   File: sec_filings\CMS\2015_Q1.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Management’s discussion and analysis of financial condition and results of operations for CMS Energy and Consumers is contained in Item 8. Financial Statements and Supplementary Data, MD&A, which is i...
#
# Processing 65: CMS - 2012_Q2
#   File: sec_filings\CMS\2012_Q2.html
#   SUCCESS: Extracted 96 characters
#   Preview: Management’s Discussion and Analysis of Financial Condition and Results of Operations 12 Item 3.
#
# Processing 66: CMS - 2013_Q1
#   File: sec_filings\CMS\2013_Q1.html
#   SUCCESS: Extracted 10000 characters
#   Preview: ITEM 7. MANAGEMENT'S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS Management's discussion and analysis of financial condition and results of operations for CMS Energy and C...
#
# Processing 67: CMS - 2016_Q4
#   File: sec_filings\CMS\2016_Q4.html
#   SUCCESS: Extracted 8332 characters
#   Preview: Management’s discussion and analysis of financial condition and results of operations for CMS Energy and Consumers is contained in Part I—Item 1. Financial Statements—MD&A, which is incorporated by re...
#
# Processing 68: GE - 2015_Q4
#   File: sec_filings\GE\2015_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: 2015 2Q FORM 10-Q 9CONSOLIDATED RESULTSTHREE AND SIX MONTHS ENDED JUNE 30(Dollars in billions)REVENUESINDUSTRIAL SEGMENT EQUIPMENT& SERVICES REVENUESEquipmentServicesCOMMENTARY: 2015 - 2014THREE MONTH...
#
# Processing 69: GE - 2014_Q2
#   File: sec_filings\GE\2014_Q2.html
#   SUCCESS: Extracted 96 characters
#   Preview: Management’s Discussion and Analysis of Financial Condition and Results of Operations 44 Item 3.
#
# Processing 70: GE - 2016_Q4
#   File: sec_filings\GE\2016_Q4.html
#   SUCCESS: Extracted 530 characters
#   Preview: Management's Discussion and Analysis of Financial Condition and Results of Operations (MD&A) 4 Key Performance Indicators 8 Consolidated Results 10 Segment Operations 14 Corporate Items and Eliminatio...
#
# Processing 71: LMT - 2014_Q2
#   File: sec_filings\LMT\2014_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: ITEM 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations. BUSINESS OVERVIEW We are a global security and aerospace company principally engaged in the research, des...
#
# Processing 72: LMT - 2015_Q2
#   File: sec_filings\LMT\2015_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: ITEM 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations. BUSINESS OVERVIEW We are a global security and aerospace company principally engaged in the research, des...
#
# Processing 73: LMT - 2015_Q3
#   File: sec_filings\LMT\2015_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: ITEM 7. Management’s Discussion and Analysis of Financial Condition and Results of Operations. Business Overview We are a global security and aerospace company principally engaged in the research, des...
#
# Processing 74: LMT - 2012_Q2
#   File: sec_filings\LMT\2012_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: ITEM 7. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS Management Overview We are a global security and aerospace company principally engaged in the research, de...
#
# Processing 75: LMT - 2012_Q4
#   File: sec_filings\LMT\2012_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: ITEM 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations. BUSINESS OVERVIEW We are a global security and aerospace company principally engaged in the research, des...
#
# Processing 76: OXY - 2015_Q4
#   File: sec_filings\OXY\2015_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations In this report, “Occidental” means Occidental Petroleum Corporation (OPC), or OPC and one or more entities...
#
# Processing 77: OXY - 2013_Q3
#   File: sec_filings\OXY\2013_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations Consolidated Results of Operations In this report, “Occidental” means Occidental Petroleum Corporation (OP...
#
# Processing 78: OXY - 2014_Q4
#   File: sec_filings\OXY\2014_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations In this report, “Occidental” means Occidental Petroleum Corporation (OPC), or OPC and one or more entities...
#
# Processing 79: OXY - 2012_Q2
#   File: sec_filings\OXY\2012_Q2.html
#   SUCCESS: Extracted 96 characters
#   Preview: Management’s Discussion and Analysis of Financial Condition and Results of Operations 18 Item 3.
#
# Processing 80: OXY - 2016_Q4
#   File: sec_filings\OXY\2016_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations In this report, “Occidental” means Occidental Petroleum Corporation (OPC), or OPC and one or more entities...
#
# Processing 81: PNW - 2015_Q4
#   File: sec_filings\PNW\2015_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: ITEM 2. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS INTRODUCTION The following discussion should be read in conjunction with Pinnacle West’s Condensed Consoli...
#
# Processing 82: PNW - 2014_Q4
#   File: sec_filings\PNW\2014_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: ITEM 2. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS INTRODUCTION The following discussion should be read in conjunction with Pinnacle West’s Condensed Consoli...
#
# Processing 83: PNW - 2014_Q2
#   File: sec_filings\PNW\2014_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: INTRODUCTION The following discussion should be read in conjunction with Pinnacle West’s Condensed Consolidated Financial Statements and APS’s Condensed Consolidated Financial Statements and the relat...
#
# Processing 84: CVS - 2015_Q4
#   File: sec_filings\CVS\2015_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Part I Item 2 Management’s Discussion and Analysis of Financial Condition and Results of Operations Overview of Our Business CVS Health Corporation, together with its subsidiaries (collectively “CVS H...
#
# Processing 85: CVS - 2013_Q3
#   File: sec_filings\CVS\2013_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Part I Item 2 Management’s Discussion and Analysis of Financial Condition and Results of Operations Overview of Our Business CVS Caremark Corporation (“CVS Caremark”, the “Company”, “we” or “us”), tog...
#
# Processing 86: CVS - 2015_Q2
#   File: sec_filings\CVS\2015_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Part I Item 2 Management’s Discussion and Analysis of Financial Condition and Results of Operations Overview of Our Business CVS Health Corporation, together with its subsidiaries (collectively “CVS H...
#
# Processing 87: CVS - 2012_Q2
#   File: sec_filings\CVS\2012_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: We refer you to the “Management’s Discussion and Analysis of Financial Condition and Results of Operations,” which includes our “Cautionary Statement Concerning Forward-Looking Statements” at the end ...
#
# Processing 88: CVS - 2012_Q4
#   File: sec_filings\CVS\2012_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Overview of Our Business CVS Caremark Corporation (“CVS Caremark”, the “Company”, “we” or “us”), together with its subsidiaries is the largest pharmacy health care provider in the United States. We ar...
#
# Processing 89: CVS - 2016_Q3
#   File: sec_filings\CVS\2016_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Part I Item 2 Management’s Discussion and Analysis of Financial Condition and Results of Operations Overview of Our Business CVS Health Corporation, together with its subsidiaries (collectively, “CVS ...
#
# Processing 90: WY - 2014_Q1
#   File: sec_filings\WY\2014_Q1.html
#   SUCCESS: Extracted 10000 characters
#   Preview: WHAT YOU WILL FIND IN THIS MD&A Our MD&A includes the following major sections: economic and market conditions affecting our operations; financial performance summary; results of our operations — cons...
#
# Processing 91: WY - 2014_Q3
#   File: sec_filings\WY\2014_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS (“MD&A”) FORWARD-LOOKING STATEMENTS This report contains statements concerning our future results and performance ...
#
# Processing 92: WY - 2013_Q2
#   File: sec_filings\WY\2013_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: WHAT YOU WILL FIND IN THIS MD&A Our MD&A includes the following major sections: economic and market conditions affecting our operations; real estate investment trust (REIT) election; financial perform...
#
# Processing 93: WY - 2015_Q4
#   File: sec_filings\WY\2015_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS (“MD&A”) FORWARD-LOOKING STATEMENTS This report contains statements concerning our future results and performance ...
#
# Processing 94: WY - 2012_Q2
#   File: sec_filings\WY\2012_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS (“MD&A”) FORWARD-LOOKING STATEMENTS This report contains statements concerning our future results and performance ...
#
# Skipping 95: File not found - EPAY/2014_Q4
#
# Skipping 96: File not found - EPAY/2015_Q4
#
# Processing 97: UVV - 2014_Q2
#   File: sec_filings\UVV\2014_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 7. Management’s Discussion and Analysis of Financial Condition and Results of Operations The following discussion and analysis of financial condition and results of operations is provided to enha...
#
# Processing 98: UVV - 2014_Q4
#   File: sec_filings\UVV\2014_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: ITEM 2. MANAGEMENT'S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS This Quarterly Report on Form 10-Q and the following “Management’s Discussion and Analysis of Financial Co...
#
# Processing 99: UVV - 2012_Q2
#   File: sec_filings\UVV\2012_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 7. Management’s Discussion and Analysis of Financial Condition and Results of Operations The following discussion and analysis of financial condition and results of operations is provided to enha...
#
# Processing 100: UVV - 2015_Q3
#   File: sec_filings\UVV\2015_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: ITEM 2. MANAGEMENT'S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS This Quarterly Report on Form 10-Q and the following “Management’s Discussion and Analysis of Financial Co...
#
# Processing 101: UVV - 2013_Q2
#   File: sec_filings\UVV\2013_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 7. Management’s Discussion and Analysis of Financial Condition and Results of Operations The following discussion and analysis of financial condition and results of operations is provided to enha...
#
# Processing 102: EMR - 2012_Q2
#   File: sec_filings\EMR\2012_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Second quarter2012sales and earnings reflected sequential improvement versus first quarter 2012 as demand in the U.S., Asia and Middle East/Africa turned positive and the impact of Thailand flooding w...
#
# Processing 103: EMR - 2015_Q2
#   File: sec_filings\EMR\2015_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Second quarter sales were$5.4 billion, down7 percent, and underlying sales were flat. Sales growth was affected by a slowdown in short-cycle industrial spending, specifically in energy-related markets...
#
# Processing 104: EMR - 2013_Q1
#   File: sec_filings\EMR\2013_Q1.html
#   SUCCESS: Extracted 10000 characters
#   Preview: First quarter sales were $5.6 billion, up 5 percent, while earnings were $454 million, an increase of 22 percent. These results reflect solid growth in the U.S. and Asia, and strong growth in Latin Am...
#
# Processing 105: MRO - 2013_Q3
#   File: sec_filings\MRO\2013_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations Beginning in 2013, we changed our reportable segments and revised our management reporting to better refle...
#
# Processing 106: MRO - 2012_Q4
#   File: sec_filings\MRO\2012_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: MARATHON OIL CORPORATIONNotes to Consolidated Financial Statements (Unaudited) Three Months Ended June 30, 2011(In millions)E&POSMIGTotalRevenues:Customer$3,220$447$13$3,680Intersegment15--15Related p...
#
# Processing 107: MRO - 2012_Q2
#   File: sec_filings\MRO\2012_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Unless the context otherwise indicates, references in this Form 10-Q to “Marathon Oil,” “we,” “our,” or “us” are references to Marathon Oil Corporation, including its wholly-owned and majority-owned s...
#
# Processing 108: MRO - 2014_Q4
#   File: sec_filings\MRO\2014_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations We are a global energy company based in Houston, Texas, with operations in North America, Europe, Africa a...
#
# Processing 109: MRO - 2015_Q4
#   File: sec_filings\MRO\2015_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations Executive Overview Outlook Operations Market Conditions Results of Operations Critical Accounting Estimate...
#
# Processing 110: CRC - 2015_Q4
#   File: sec_filings\CRC\2015_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations Except when the context otherwise requires or where otherwise indicated, (1) all references to CRC, the Co...
#
# Processing 111: CRC - 2016_Q3
#   File: sec_filings\CRC\2016_Q3.html
#   SUCCESS: Extracted 2951 characters
#   Preview: Commodity Price Risk We currently have the following Brent-based crude oil and NYMEX-based gas hedges: 201620172018Q3Q4Q1 - Q4Q1 - Q4Crude OilCalls:Barrels per day19,00025,00010,50021,500Weighted-aver...
#
# Processing 112: CRC - 2014_Q3
#   File: sec_filings\CRC\2014_Q3.html
#   FAILED: Could not extract MD&A
#
# Processing 113: GATX - 2014_Q4
#   File: sec_filings\GATX\2014_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: A detailed discussion of the known material risks and uncertainties that could cause actual results and events to differ materially from such forward-looking statements is included in ourAnnual Report...
#
# Processing 114: GATX - 2014_Q2
#   File: sec_filings\GATX\2014_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: A detailed discussion of the known material risks and uncertainties that could cause actual results and events to differ materially from such forward-looking statements is included in ourAnnual Report...
#
# Processing 115: GATX - 2015_Q4
#   File: sec_filings\GATX\2015_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Operating results for thethree and sixmonths endedJune 30, 2015are not necessarily indicative of the results we may achieve for the entire year ending December 31, 2015. For more information about our...
#
# Processing 116: GATX - 2013_Q2
#   File: sec_filings\GATX\2013_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 7. Management’s Discussion and Analysis of Financial Condition and Results of Operations OVERVIEW Headquartered in Chicago, Illinois, GATX Corporation (“GATX” or the “Company”) leases, operates, ...
#
# Processing 117: GATX - 2016_Q4
#   File: sec_filings\GATX\2016_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Operating results for thethree and sixmonths endedJune 30, 2016are not necessarily indicative of the results we may achieve for the entire year ending December 31, 2016. For more information about our...
#
# Processing 118: EPD - 2013_Q4
#   File: sec_filings\EPD\2013_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Anchor Item 2. Management's Discussion and Analysis of Financial Condition and Results of Operations For the three and nine months ended September 30, 2013 and 2012. The following information should b...
#
# Processing 119: EPD - 2014_Q4
#   File: sec_filings\EPD\2014_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Anchor Item 2. Management's Discussion and Analysis of Financial Condition and Results of Operations For the Three and Nine Months Ended September 30, 2014 and 2013. The following information should b...
#
# Processing 120: EPD - 2015_Q3
#   File: sec_filings\EPD\2015_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Anchor Item 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations For the Three Months Ended March 31, 2015 and 2014. The following information should be read in con...
#
# Processing 121: EPD - 2013_Q1
#   File: sec_filings\EPD\2013_Q1.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Anchor Item 7. Management's Discussion and Analysis of Financial Condition and Results of Operations For the Years Ended December 31, 2012, 2011 and 2010 The following information should be read in co...
#
# Processing 122: RBA - 2016_Q4
#   File: sec_filings\RBA\2016_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: ITEM 2: MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS About Us Ritchie Bros. Auctioneers Incorporated (“Ritchie Bros.”, the “Company”, “we”, or “us”) (NYSE & TS...
#
# Processing 123: CBT - 2012_Q3
#   File: sec_filings\CBT\2012_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 7. Management’s Discussion and Analysis of Financial Condition and Results of Operations Critical Accounting Policies The preparation of our financial statements requires management to make estim...
#
# Processing 124: CBT - 2012_Q2
#   File: sec_filings\CBT\2012_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 7. Management’s Discussion and Analysis of Financial Condition and Results of Operations Critical Accounting Policies The preparation of our financial statements requires management to make estim...
#
# Processing 125: CBT - 2015_Q2
#   File: sec_filings\CBT\2015_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 7. Management’s Discussion and Analysis of Financial Condition and Results of Operations Critical Accounting Policies The preparation of our financial statements requires management to make estim...
#
# Processing 126: CBT - 2015_Q4
#   File: sec_filings\CBT\2015_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Management’s Discussion and Analysis of Financial Condition and Results of Operations Critical Accounting Policies The preparation of our financial statements requires management to make estimates and...
#
# Processing 127: CBT - 2014_Q1
#   File: sec_filings\CBT\2014_Q1.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 7. Management’s Discussion and Analysis of Financial Condition and Results of Operations Critical Accounting Policies The preparation of our financial statements requires management to make estim...
#
# Processing 128: CBT - 2016_Q3
#   File: sec_filings\CBT\2016_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Management’s Discussion and Analysis Financial Condition and Results of Operations Critical Accounting Policies The preparation of our financial statements requires management to make estimates and ju...
#
# Processing 129: PSX - 2014_Q4
#   File: sec_filings\PSX\2014_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Table of Contents Item 2. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS Management’s Discussion and Analysis is the company’s analysis of its financial performa...
#
# Processing 130: PSX - 2016_Q4
#   File: sec_filings\PSX\2016_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Table of Contents Item 2. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS Management’s Discussion and Analysis is the company’s analysis of its financial performa...
#
# Processing 131: PSX - 2015_Q3
#   File: sec_filings\PSX\2015_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Table of Contents Item 2. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS Management’s Discussion and Analysis is the company’s analysis of its financial performa...
#
# Processing 132: PSX - 2014_Q2
#   File: sec_filings\PSX\2014_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Table of Contents Item 2. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS Management’s Discussion and Analysis is the company’s analysis of its financial performa...
#
# Processing 133: PSX - 2013_Q1
#   File: sec_filings\PSX\2013_Q1.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Table of Contents Index to Financial Statements Item 7. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS Management’s Discussion and Analysis is the company’s anal...
#
# Processing 134: EFX - 2012_Q2
#   File: sec_filings\EFX\2012_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: BUSINESS OVERVIEW We are a leading global provider of information solutions, employment and income verifications and human resources business process outsourcing services. We leverage some of the larg...
#
# Processing 135: EFX - 2013_Q3
#   File: sec_filings\EFX\2013_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: BUSINESS OVERVIEW We are a leading global provider of information solutions, employment and income verifications and human resources business process outsourcing services. We leverage some of the larg...
#
# Processing 136: EFX - 2015_Q4
#   File: sec_filings\EFX\2015_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: ITEM 2. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS As used herein, the terms Equifax, the Company, we, our and us refer to Equifax Inc., a Georgia corporatio...
#
# Processing 137: EFX - 2014_Q3
#   File: sec_filings\EFX\2014_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: ITEM 2. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS As used herein, the terms Equifax, the Company, we, our and us refer to Equifax Inc., a Georgia corporatio...
#
# Processing 138: EFX - 2012_Q4
#   File: sec_filings\EFX\2012_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: BUSINESS OVERVIEW We are a leading global provider of information solutions, employment and income verifications and human resources business process outsourcing services. We leverage some of the larg...
#
# Processing 139: XOM - 2013_Q3
#   File: sec_filings\XOM\2013_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: PART I. FINANCIAL INFORMATIONItem 1. Financial StatementsEXXON MOBIL CORPORATIONCONDENSED CONSOLIDATED STATEMENT OF INCOME(millions of dollars)Three Months EndedSix Months EndedJune 30,June 30,2013201...
#
# Processing 140: XOM - 2014_Q4
#   File: sec_filings\XOM\2014_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: PART I. FINANCIAL INFORMATIONItem 1. Financial StatementsEXXON MOBIL CORPORATIONCONDENSED CONSOLIDATED STATEMENT OF INCOME(millions of dollars)Three Months EndedNine Months EndedSeptember 30,September...
#
# Processing 141: XOM - 2016_Q2
#   File: sec_filings\XOM\2016_Q2.html
#   SUCCESS: Extracted 96 characters
#   Preview: Item 7. Management’s Discussion and Analysis of Financial Condition and Results of Operations 30
#
# Processing 142: QCOM - 2015_Q2
#   File: sec_filings\QCOM\2015_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: ITEM 2. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS information should be read in conjunction with the condensed consolidated financial statements and the not...
#
# Processing 143: QCOM - 2016_Q4
#   File: sec_filings\QCOM\2016_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 7. Management s Discussion and Analysis of Financial Condition and Results of Operations In addition to historical information, the following discussion contains forward-looking statements that a...
#
# Processing 144: CSX - 2014_Q3
#   File: sec_filings\CSX\2014_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Table of Contents CSX CORPORATION ITEM 2. MANAGEMENT'S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS SECOND QUARTER 2014 HIGHLIGHTS Revenue of $3.2 billion $198 million year...
#
# Processing 145: CSX - 2015_Q4
#   File: sec_filings\CSX\2015_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Table of Contents CSX CORPORATION ITEM 2. MANAGEMENT'S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS THIRD QUARTER 2015 HIGHLIGHTS Revenue declined $282 million $2.9 billion...
#
# Processing 146: CSX - 2012_Q4
#   File: sec_filings\CSX\2012_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Table of Contents CSX CORPORATION ITEM 2. MANAGEMENT'S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS STRATEGIC OVERVIEW CSX provides rail-based freight transportation servic...
#
# Processing 147: CSX - 2012_Q2
#   File: sec_filings\CSX\2012_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Table of Contents CSX CORPORATION ITEM 2. MANAGEMENT'S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS STRATEGIC OVERVIEW CSX provides rail-based freight transportation servic...
#
# Processing 148: CSX - 2013_Q3
#   File: sec_filings\CSX\2013_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Table of Contents CSX CORPORATION ITEM 2. MANAGEMENT'S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS SECOND QUARTER 2013 HIGHLIGHTS Record revenue of $3.1 billion increased ...
#
# Processing 149: CSX - 2016_Q4
#   File: sec_filings\CSX\2016_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Table of Contents CSX CORPORATION ITEM 2. MANAGEMENT'S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS THIRD QUARTER 2016 HIGHLIGHTS Revenue declined $229 million $2.7 billion...
#
# Processing 150: CSX - 2011_Q2
#   File: sec_filings\CSX\2011_Q2.html
#   SUCCESS: Extracted 226 characters
#   Preview: Management's Discussion and Analysis of Financial Condition and Results of Operations ……………………………………………………………………...........................................................................................
#
# Processing 151: HAL - 2013_Q3
#   File: sec_filings\HAL\2013_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Table of Contents Item 2. Management's Discussion and Analysis of Financial Condition and Results of Operations EXECUTIVE OVERVIEW Organization We are a leading provider of services and products to th...
#
# Processing 152: HAL - 2015_Q1
#   File: sec_filings\HAL\2015_Q1.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Table of Contents Item 2. Management's Discussion and Analysis of Financial Condition and Results of Operations EXECUTIVE OVERVIEW Organization We are a leading provider of services and products to th...
#
# Processing 153: HAL - 2015_Q4
#   File: sec_filings\HAL\2015_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Table of Contents Item 2. Management's Discussion and Analysis of Financial Condition and Results of Operations EXECUTIVE OVERVIEW Organization We are a leading provider of services and products to th...
#
# Processing 154: HAL - 2012_Q2
#   File: sec_filings\HAL\2012_Q2.html
#   SUCCESS: Extracted 96 characters
#   Preview: Management’s Discussion and Analysis of Financial Condition and Results of Operations 26 Item 3.
#
# Skipping 155: File not found - LB/2015_Q1
#
# Skipping 156: File not found - LB/2013_Q3
#
# Skipping 157: File not found - LB/2015_Q4
#
# Skipping 158: File not found - UFS/2015_Q4
#
# Skipping 159: File not found - UFS/2014_Q2
#
# Skipping 160: File not found - UFS/2012_Q2
#
# Skipping 161: File not found - UFS/2015_Q1
#
# Skipping 162: File not found - UFS/2012_Q3
#
# Processing 163: HES - 2015_Q2
#   File: sec_filings\HES\2015_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Management’s Discussion and Analysis of Financial Condition and Results of Operations. Overview Hess Corporation is a global Exploration and Production (E&P) company that develops, produces, purchases...
#
# Processing 164: HES - 2013_Q3
#   File: sec_filings\HES\2013_Q3.html
#   SUCCESS: Extracted 26712 characters
#   Preview: Management’s Discussion and Analysis of Financial Condition and Results of Operations. Overview In March 2013, Hess Corporation (the Corporation) announced an asset sales program that includes divesti...
#
# Processing 165: HES - 2015_Q3
#   File: sec_filings\HES\2015_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: anagement’s Discussion and Analysis of Financial Condition and Results of Operations. Overview Hess Corporation is a global Exploration and Production (E&P) company that explores for, develops, produc...
#
# Processing 166: HES - 2016_Q3
#   File: sec_filings\HES\2016_Q3.html
#   SUCCESS: Extracted 10000 characters
# ...
#
# Processing 1968: RCL - 2016_Q4
#   File: sec_filings\RCL\2016_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Table of Contents Item 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations Cautionary Note Concerning Forward-Looking Statements The discussion under this caption ...
#
# Processing 1969: NYT - 2012_Q2
#   File: sec_filings\NYT\2012_Q2.html
#   SUCCESS: Extracted 36500 characters
#   Preview: Management’s Discussion and Analysis of Financial Condition and Results of OperationsWe are a leading global, multimedia news and information company that currently includes newspapers, digital busine...
#
# Processing 1970: HPE - 2015_Q3
#   File: sec_filings\HPE\2015_Q3.html
#   FAILED: Could not extract MD&A
#
# Skipping 1971: File not found - ICLR/2016_Q1
#
# Processing 1972: NXPI - 2016_Q4
#   File: sec_filings\NXPI\2016_Q4.html
#   FAILED: Could not extract MD&A
#
# Processing 1973: NXPI - 2015_Q4
#   File: sec_filings\NXPI\2015_Q4.html
#   FAILED: Could not extract MD&A
#
# Processing 1974: NXPI - 2014_Q4
#   File: sec_filings\NXPI\2014_Q4.html
#   FAILED: Could not extract MD&A
#
# Processing 1975: GPRE - 2014_Q2
#   File: sec_filings\GPRE\2014_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2 . Management’s Discussion and Analysis of Financial Condition and Results of Operations. General The following discussion and analysis provides information which management believes is relevant...
#
# Processing 1976: MX - 2015_Q1
#   File: sec_filings\MX\2015_Q1.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations The following discussion and analysis should be read in conjunction with the unaudited consolidated financ...
#
# Processing 1977: MX - 2014_Q2
#   File: sec_filings\MX\2014_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations The following discussion and analysis should be read in conjunction with the unaudited consolidated financ...
#
# Processing 1978: MX - 2012_Q2
#   File: sec_filings\MX\2012_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations The following discussion and analysis should be read in conjunction with the unaudited consolidated financ...
#
# Processing 1979: MX - 2016_Q3
#   File: sec_filings\MX\2016_Q3.html
#   FAILED: Could not extract MD&A
#
# Processing 1980: MX - 2013_Q2
#   File: sec_filings\MX\2013_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations The following discussion and analysis should be read in conjunction with the unaudited consolidated financ...
#
# Processing 1981: HL - 2013_Q2
#   File: sec_filings\HL\2013_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: In March 2012, Hecla Limited received notice of a complaint filed against it by the United Steel Workers, Local 5114, with the Federal Mine Safety Health Review Commission for compensation for bargain...
#
# Processing 1982: PED - 2015_Q4
#   File: sec_filings\PED\2015_Q4.html
#   SUCCESS: Extracted 95 characters
#   Preview: Management’s Discussion and Analysis of Financial Condition and Results of Operations 1 Item 3.
#
# Processing 1983: SIG - 2016_Q3
#   File: sec_filings\SIG\2016_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Table of Contents PART I. FINANCIAL INFORMATION ITEM 1. FINANCIAL STATEMENTS SIGNET JEWELERS LIMITED CONDENSED CONSOLIDATED INCOME STATEMENTS (Unaudited) 13 weeks ended(in millions, except per share a...
#
# Processing 1984: VSTO - 2016_Q1
#   File: sec_filings\VSTO\2016_Q1.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Table of Contents ITEM 2. MANAGEMENT'S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS (Dollar amounts in thousands unless otherwise indicated) Forward-Looking Information is ...
#
# Processing 1985: VSTO - 2016_Q3
#   File: sec_filings\VSTO\2016_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Table of Contents ITEM 2. MANAGEMENT'S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS (Dollar amounts in thousands unless otherwise indicated) Forward-Looking Information is ...
#
# Skipping 1986: File not found - KRA/2015_Q4
#
# Processing 1987: VRNT - 2013_Q1
#   File: sec_filings\VRNT\2013_Q1.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations The following management’s discussion and analysis is provided to assist readers in understanding our fina...
#
# Processing 1988: VRNT - 2014_Q2
#   File: sec_filings\VRNT\2014_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations The following management’s discussion and analysis is provided to assist readers in understanding our fina...
#
# Processing 1989: VRNT - 2012_Q2
#   File: sec_filings\VRNT\2012_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: The following management’s discussion and analysis is provided to assist readers in understanding our financial condition, results of operations, and cash flows. This discussion should be read in conj...
#
# Processing 1990: GTN - 2016_Q2
#   File: sec_filings\GTN\2016_Q2.html
#   SUCCESS: Extracted 96 characters
#   Preview: Management's Discussion and Analysis of Financial Condition and Results of Operations 20 Item 3.
#
# Processing 1991: GTN - 2016_Q3
#   File: sec_filings\GTN\2016_Q3.html
#   SUCCESS: Extracted 96 characters
#   Preview: Management's Discussion and Analysis of Financial Condition and Results of Operations 21 Item 3.
#
# Processing 1992: PYPL - 2016_Q3
#   File: sec_filings\PYPL\2016_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Table of Contents Item 2: Management's Discussion and Analysis of Financial Condition and Results of Operations This Quarterly Report on Form 10-Q contains forward-looking statements within the meanin...
#
# Processing 1993: BR - 2016_Q2
#   File: sec_filings\BR\2016_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Table of Contents Item 2. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS The following discussion should be read in conjunction with our Condensed Consolidated F...
#
# Processing 1994: BR - 2013_Q3
#   File: sec_filings\BR\2013_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS The following discussion should be read in conjunction with our Condensed Consolidated Financial Statement...
#
# Processing 1995: BR - 2012_Q2
#   File: sec_filings\BR\2012_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS The following discussion should be read in conjunction with our Condensed Consolidated Financial Statement...
#
# Skipping 1996: File not found - ETM/2012_Q2
#
# Processing 1997: PRA - 2013_Q4
#   File: sec_filings\PRA\2013_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Table of Contents ITEM 2. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS. The following discussion should be read in conjunction with the Condensed Consolidated ...
#
# Processing 1998: KODK - 2016_Q4
#   File: sec_filings\KODK\2016_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations CAUTIONARY STATEMENT PURSUANT TO SAFE HARBOR PROVISIONS OF THE PRIVATE SECURITIES LITIGATION REFORM ACT OF...
#
# Processing 1999: SCS - 2012_Q2
#   File: sec_filings\SCS\2012_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Management’s Discussion and Analysis of Financial Condition and Results of Operations: This management’s discussion and analysis of financial condition and results of operations should be read in conj...
#
# Processing 2000: SCS - 2014_Q1
#   File: sec_filings\SCS\2014_Q1.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Table of Contents Item 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations: This management’s discussion and analysis of financial condition and results of operati...
#
# Processing 2001: ENTG - 2016_Q1
#   File: sec_filings\ENTG\2016_Q1.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Table of Contents Item 7. Management’s Discussion and Analysis of Financial Condition and Results of Operations. The following discussion and analysis of the Company’s consolidated financial condition...
#
# Processing 2002: FISV - 2015_Q2
#   File: sec_filings\FISV\2015_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: ITEM 2. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS Forward-Looking Statements This quarterly report contains “forward-looking statements” intended to qualify...
#
# Processing 2003: FISV - 2016_Q1
#   File: sec_filings\FISV\2016_Q1.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 7. Management’s Discussion and Analysis of Financial Condition and Results of Operations Management’s discussion and analysis of financial condition and results of operations is provided as a sup...
#
# Processing 2004: FANG - 2016_Q4
#   File: sec_filings\FANG\2016_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: ITEM 2. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS The following discussion and analysis should be read in conjunction with our unaudited consolidated financ...
#
# Skipping 2005: File not found - NBL/2016_Q1
#
# Processing 2006: BIO - 2012_Q2
#   File: sec_filings\BIO\2012_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations This discussion should be read in conjunction with the information contained in both our Consolidated Fina...
#
# Processing 2007: BIO - 2014_Q4
#   File: sec_filings\BIO\2014_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations This discussion should be read in conjunction with the information contained in both our Consolidated Fina...
#
# Processing 2008: PRAA - 2012_Q2
#   File: sec_filings\PRAA\2012_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations Cautionary Statements Pursuant to Safe Harbor Provisions of the Private Securities Litigation Reform Act o...
#
# Processing 2009: CDNS - 2016_Q1
#   File: sec_filings\CDNS\2016_Q1.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations The following discussion should be read in conjunction with the condensed consolidated financial statement...
#
# Processing 2010: PTC - 2016_Q2
#   File: sec_filings\PTC\2016_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: ITEM 2. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS Forward-Looking Statements Statements in this Quarterly Report on Form 10-Q that are not historic facts, i...
#
# Processing 2011: SRCL - 2016_Q1
#   File: sec_filings\SRCL\2016_Q1.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 7. Management’s Discussion and Analysis of Financial Condition and Results of Operations The following discussion of our financial condition and results of operations should be read in conjunctio...
#
# Processing 2012: SRCL - 2016_Q4
#   File: sec_filings\SRCL\2016_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: ITEM 2. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS We are a business-to-business services provider with a focus on regulated and compliance solutions for hea...
#
# Processing 2013: VVV - 2016_Q4
#   File: sec_filings\VVV\2016_Q4.html
#   FAILED: Could not extract MD&A
#
# Processing 2014: KOS - 2015_Q2
#   File: sec_filings\KOS\2015_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 7. Management's Discussion and Analysis of Financial Condition and Results of Operations The following discussion and analysis contains forward-looking statements that involve risks and uncertain...
#
# Processing 2015: KOP - 2012_Q2
#   File: sec_filings\KOP\2012_Q2.html
#   SUCCESS: Extracted 2932 characters
#   Preview: MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS This report and any documents incorporated herein by reference contain “forward-looking statements” within the mea...
#
# Processing 2016: STX - 2012_Q2
#   File: sec_filings\STX\2012_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: OPERATIONS The following is a discussion of the financial condition and results of operations for our fiscal quarters ended March 30, 2012, December 30, 2011 and April 1, 2011, referred to herein as t...
#
# Processing 2017: MANT - 2012_Q2
#   File: sec_filings\MANT\2012_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations Forward-Looking Statements This Quarterly Report on Form 10-Q contains forward-looking statements that inv...
#
# Processing 2018: NOG - 2016_Q2
#   File: sec_filings\NOG\2016_Q2.html
#   SUCCESS: Extracted 96 characters
#   Preview: Item 7. Management's Discussion and Analysis of Financial Condition and Results of Operations 45
#
# Skipping 2019: File not found - IRS/2010_Q4
#
# Processing 2020: IT - 2016_Q1
#   File: sec_filings\IT\2016_Q1.html
#   SUCCESS: Extracted 10000 characters
#   Preview: ITEM 2. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS The purpose of the following Management’s Discussion and Analysis (“MD&A”) is to help facilitate the under...
#
# Processing 2021: SBAC - 2013_Q3
#   File: sec_filings\SBAC\2013_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: ITEM 7. MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONS The following discussion of our financial condition and results of operations should be read in conjunctio...
#
# Processing 2022: XPER - 2016_Q4
#   File: sec_filings\XPER\2016_Q4.html
#   FAILED: Could not extract MD&A
#
# Processing 2023: IMO - 2016_Q4
#   File: sec_filings\IMO\2016_Q4.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations. OPERATING RESULTS First quarter 2016 vs. first quarter 2015 The company’s net loss for the first quarter ...
#
# Processing 2024: NVR - 2012_Q3
#   File: sec_filings\NVR\2012_Q3.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2. Management’s Discussion and Analysis of Financial Condition and Results of Operations (dollars in thousands) Forward-Looking Statements Some of the statements in this Form 10-Q, as well as sta...
#
# Processing 2025: KALU - 2016_Q2
#   File: sec_filings\KALU\2016_Q2.html
#   SUCCESS: Extracted 10000 characters
#   Preview: Item 2. Management s Discussion and Analysis of Financial Condition and Results of Operations This Item should be read in conjunction with Part I, Item 1. Financial Statements of this Quarterly Report...
#
# Skipping 2026: File not found - CRESY/2012_Q4
#
# Skipping 2027: File not found - CRESY/2012_Q2
#
# Skipping 2028: File not found - CRESY/2014_Q3
#
# Extraction complete!
# Success: 1639, Failed/Not Found: 390
# Success rate: 80.8%
# \nSaved enhanced data to '02_credit_ratings_with_mda.csv'
# \nRows with MD&A data: 1639
# Rows without MD&A data: 390
# \nSample of extracted MD&A data:
#   WHR (2015_Q4) - Rating: A
#   WHR (2014_Q1) - Rating: BBB
#   WHR (2015_Q1) - Rating: BBB
#   WHR (2012_Q2) - Rating: BBB
#   WHR (2016_Q4) - Rating: BBB
